# %%
import pandas as pd

df1 = df.iloc[:5]
df2 = df.iloc[5:10]

new_df = pd.concat([df1, df2])
print(df1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2
# ----> 3 df1 = df.iloc[:5]
#       4 df2 = df.iloc[5:10]
#       5
#       6 new_df = pd.concat([df1, df2])
#
# NameError: name 'df' is not defined
