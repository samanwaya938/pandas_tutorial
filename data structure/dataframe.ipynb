# %%
import pandas as pd

data = {
  "Name": ["A","B","C"],
  "Age": [25,35,30],
  "Gender": ["M","F","M"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Name  Age Gender
# 0    A   25      M
# 1    B   35      F
# 2    C   30      M

# %%
print(df[["Age", "Gender"]])
# Out:
#    Age Gender
# 0   25      M
# 1   35      F
# 2   30      M

# %%
sales = {
  "Product": ["Laptop","Mobile"],
  "Price": [50000,10000],
  "Quantity": [5,10]
}

df2 = pd.DataFrame(sales)
print(df2)
# Out:
#   Product  Price  Quantity
# 0  Laptop  50000         5
# 1  Mobile  10000        10

# %%
print(df2[["Product", "Quantity"]])
# Out:
#   Product  Quantity
# 0  Laptop         5
# 1  Mobile        10
