# %%
import pandas as pd

data = {
  "Date" : ["2026-01-01", "2025-02-01", "2024-03-01"]
}

df_date = pd.DataFrame(data)
df_date["Date"] = pd.to_datetime(df_date["Date"])
df_date
# Out:
#         Date
# 0 2026-01-01
# 1 2025-02-01
# 2 2024-03-01

# %%
df_date["Date"].dtype
# Out:
# dtype('<M8[us]')

# %%
df_date["Year"] = df_date["Date"].dt.year
df_date["Month"] = df_date["Date"].dt.month
df_date["Day"] = df_date["Date"].dt.day

df_date
# Out:
#         Date  Year  Month  Day
# 0 2026-01-01  2026      1    1
# 1 2025-02-01  2025      2    1
# 2 2024-03-01  2024      3    1

# %%
df_date[df_date["Date"] > "2025-01-31"]
# Out:
#         Date  Year  Month  Day
# 0 2026-01-01  2026      1    1
# 1 2025-02-01  2025      2    1

# %%
dates = pd.date_range(start="2023-01-01", periods=5, freq="B")
dates
# Out:
# DatetimeIndex(['2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
#                '2023-01-06'],
#               dtype='datetime64[us]', freq='B')

# %%
df_date.set_index("Date", inplace=True)
df_date
# Out:
#             Year  Month  Day
# Date
# 2026-01-01  2026      1    1
# 2025-02-01  2025      2    1
# 2024-03-01  2024      3    1

# %%
df_date.sort_index()
# Out:
#             Year  Month  Day
# Date
# 2024-03-01  2024      3    1
# 2025-02-01  2025      2    1
# 2026-01-01  2026      1    1
